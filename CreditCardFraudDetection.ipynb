# %%
import pandas as pd

# %%
df=pd.read_csv("creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
pd.options.display.max_columns= None
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc= StandardScaler()
df['Amount']=sc.fit_transform(pd.DataFrame(df['Amount']))
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
df=df.drop(['Time'],axis=1)
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
df.duplicated().any()
# Out:
# np.True_

# %%
df=df.drop_duplicates()
df.shape
# Out:
# (275663, 30)

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %% [markdown]
# #As our data is very large so we will check for the unique values in our columns

# %%
print(df['Class'].nunique())
# Out:
# 2

# %%
df['Class'] = df['Class'].astype('category')

# %%
print("Number of columns: {}".format(df.shape[1]))
print("Number of rows: {}".format(df.shape[0]))
# Out:
# Number of columns: 30
# Number of rows: 275663

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %%
import seaborn as sns
from matplotlib import pyplot as plt
plt.style.use('ggplot')

# %%
sns.countplot(df['Class'])
plt.show()

# %% [markdown]
# #From the above observation we come to know that our data is highly imbalance

# %%
X=df.drop('Class',axis=1)
Y=df['Class']

# %%
print(f"Shape of X: {X.shape}")
print(f"Shape of Y: {Y.shape}")
# Out:
# Shape of X: (275663, 29)
# Shape of Y: (275663,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2, random_state=42)

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score

# %%
classifier={
              "Logistic Regression":LogisticRegression(),
               "Decision Tree Classifier":DecisionTreeClassifier()
}
for name, clf in classifier.items():
    print(f"\n========{name}======")
    clf.fit(X_train,Y_train)
    Y_pred=clf.predict(X_test)
    print(f"\n Accuracy:{accuracy_score(Y_test,Y_pred)}")
    print(f"\n Precision:{precision_score(Y_test,Y_pred)}")
    print(f"\n Recall:{recall_score(Y_test,Y_pred)}")
    print(f"\n F1 score:{f1_score(Y_test,Y_pred)}")
# Out:
# ========Logistic Regression======
#
#  Accuracy:0.9992563437505668
#
#  Precision:0.890625
#
#  Recall:0.6263736263736264
#
#  F1 score:0.7354838709677419
#
# ========Decision Tree Classifier======
#
#  Accuracy:0.9989298605191084
#
#  Precision:0.6632653061224489
#
#  Recall:0.7142857142857143
#
#  F1 score:0.6878306878306878

# %%
#Undersampling
normal=df[df['Class']==0]
fraud=df[df['Class']==1]

# %%
normal.shape
# Out:
# (275190, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
normal_sample=normal.sample(n=473)

# %%
normal_sample.shape
# Out:
# (473, 30)

# %%
new_df=pd.concat([normal_sample,fraud],ignore_index=True)
new_df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.133315  0.649347  0.255110 -0.697511 -1.664243  0.571653  1.468827
# 1  2.090556 -0.194497 -1.490012  0.069883  0.329127 -0.327383 -0.002302
# 2 -1.110356  1.160035 -1.802748 -1.449006  1.759889 -0.885924  1.595724
# 3 -1.107304  0.223140  1.609996 -1.472949  0.712396 -0.460053  1.277491
# 4 -1.350348  1.444447  2.677360  4.720120 -0.724403  2.990399 -1.814565
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0 -0.484211 -0.123137 -1.175053  0.355908  0.886760 -0.437461  0.347850
# 1 -0.070469  0.490642  0.270605 -0.110820  0.302848 -0.759530  0.593432
# 2 -0.319065  0.480971  0.673519 -1.889332 -0.800030 -0.603993  0.447608
# 3 -0.529253  0.348916  0.491886  1.684259  0.218791 -0.725343 -0.324210
# 4 -2.601835 -0.101472  1.229504 -2.444327  0.426481  1.357860 -1.450026
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
new_df['Class'].value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
X=new_df.drop('Class',axis=1)
Y=new_df['Class']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2, random_state=42)

# %%
classifier={
              "Logistic Regression":LogisticRegression(),
               "Decision Tree Classifier":DecisionTreeClassifier()
}
for name, clf in classifier.items():
    print(f"\n========{name}======")
    clf.fit(X_train,Y_train)
    Y_pred=clf.predict(X_test)
    print(f"\n Accuracy:{accuracy_score(Y_test,Y_pred)}")
    print(f"\n Precision:{precision_score(Y_test,Y_pred)}")
    print(f"\n Recall:{recall_score(Y_test,Y_pred)}")
    print(f"\n F1 score:{f1_score(Y_test,Y_pred)}")
# Out:
# ========Logistic Regression======
#
#  Accuracy:0.9473684210526315
#
#  Precision:0.9893617021276596
#
#  Recall:0.9117647058823529
#
#  F1 score:0.9489795918367347
#
# ========Decision Tree Classifier======
#
#  Accuracy:0.9263157894736842
#
#  Precision:0.9313725490196079
#
#  Recall:0.9313725490196079
#
#  F1 score:0.9313725490196079

# %%
#OverSampling
X=df.drop('Class',axis=1)
Y=df['Class']

# %%
X.shape
# Out:
# (275663, 29)

# %%
Y.shape
# Out:
# (275663,)

# %%
from imblearn.over_sampling import SMOTE

# %%
X_res,Y_res=SMOTE().fit_resample(X,Y)

# %%
Y_res.value_counts()
# Out:
# Class
# 0    275190
# 1    275190
# Name: count, dtype: int64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X_res,Y_res,test_size=0.2, random_state=42)

# %%
classifier={
              "Logistic Regression":LogisticRegression(),
               "Decision Tree Classifier":DecisionTreeClassifier()
}
for name, clf in classifier.items():
    print(f"\n========{name}======")
    clf.fit(X_train,Y_train)
    Y_pred=clf.predict(X_test)
    print(f"\n Accuracy:{accuracy_score(Y_test,Y_pred)}")
    print(f"\n Precision:{precision_score(Y_test,Y_pred)}")
    print(f"\n Recall:{recall_score(Y_test,Y_pred)}")
    print(f"\n F1 score:{f1_score(Y_test,Y_pred)}")
# Out:
# ========Logistic Regression======
#
#  Accuracy:0.9446473345688433
#
#  Precision:0.9728893529798507
#
#  Recall:0.9147137428867517
#
#  F1 score:0.9429050666716643
#
# ========Decision Tree Classifier======
#
#  Accuracy:0.9981103964533595
#
#  Precision:0.9972413292437249
#
#  Recall:0.9989818737159791
#
#  F1 score:0.9981108426731576

# %%
dtc=DecisionTreeClassifier()
dtc.fit(X_res,Y_res)
# Out:
# DecisionTreeClassifier()

# %%
import joblib

# %%
joblib.dump(dtc,"credit_card_model.pkl")
# Out:
# ['credit_card_model.pkl']

# %%
model=joblib.load("credit_card_model.pkl")

# %%
pred=model.predict([[	
1	-1.3598071336738,	-0.0727811733098497,	2.53634673796914,	1.37815522427443,
2	1.19185711131486,	0.26615071205963,	0.16648011335321,	0.448154078460911,
3	-1.35835406159823,	-1.34016307473609,	1.77320934263119,	0.379779593034328,
4	-0.966271711572087,	-0.185226008082898,	1.79299333957872,	-0.863291275036453,
5	-1.15823309349523	,0.877736754848451,	1.548717846511,	0.403033933955121,
6	-0.425965884412454,	0.960523044882985,	1.14110934232219,	-0.168252079760302,
7	1.22965763450793,	0.141003507049326,	0.0453707735899449,	1.20261273673594,
8	-0.644269442348146,	1.41796354547385,	1.0743803763556,	-0.492199018495015]])
# Out:
#   Cell In[68], line 3
#     2	1.19185711131486,	0.26615071205963,	0.16648011335321,	0.448154078460911,
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
pred=[0]

# %%
if pred[0]==0:
    print("Normal Transaction")
else:
    print("Fraud Transaction")
# Out:
# Normal Transaction
